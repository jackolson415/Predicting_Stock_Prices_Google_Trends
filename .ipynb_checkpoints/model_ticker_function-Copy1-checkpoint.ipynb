# %%
import capstone_utils as cu
# %matplotlib inline

# %% [markdown]
# ---

# %%
def model_ticker(ticker):
    myticker = ticker
    df = cu.create_ticker_df(ticker)

    y_train, y_test = cu.train_test_split_arima(df)

    cu.interpret_dftest(cu.adfuller(y_train))

    best_arima_order = cu.find_best_aic(y_train)

    model = cu.ARIMA(endog = y_train.astype(float).dropna(), # endog = Y variable
                  order = best_arima_order)

    # Fit ARIMA model.
    arima = model.fit()

    # Generate predictions based on test set.
    preds = model.predict(params = arima.params)
    preds_cuttoff = preds.shape[0]-64
    preds= preds[preds_cuttoff:]

    cu.plt.figure(figsize=(10,6))
    # Plot training data.
    cu.plt.plot(y_train.index, cu.pd.DataFrame(y_train), color = 'blue', label = 'Training Adjusted Close')

    # Plot testing data.
    cu.plt.plot(y_test.index, cu.pd.DataFrame(y_test), color = 'orange', label = 'Testing Adjusted Close')

    # Plot predicted test values.
    cu.plt.plot(y_test.index, preds, color = 'green', label = 'Arima Predictions')
    
    cu.plt.legend()

    cu.plt.title(label = f'{myticker} Daily % Return with ARIMA(2, 1, 3) Predictions', fontsize=16)
    cu.plt.show();

    start =df.iloc[-65]['adjusted_close']

    predicted_adj_close = cu.make_predicted_adj_close_df(start, preds)

    close_train = df[df.index < cu.datetime(year = 2021, month = 3, day = 1)]
    close_test = df[df.index > cu.datetime(year = 2021, month = 3, day = 1)]
    close_train = close_train['adjusted_close']
    close_test = close_test['adjusted_close'] 
    close_train = cu.pd.DataFrame(close_train)
    close_test = cu.pd.DataFrame(close_test)

    cu.plt.figure(figsize=(10,6))

    # Plot training data.
    cu.plt.plot(close_train.index, cu.pd.DataFrame(close_train), color = 'blue', label = 'Training Adjusted Close')

    # Plot testing data.
    cu.plt.plot(close_test.index, cu.pd.DataFrame(close_test), color = 'orange', label = 'Testing Adjusted Close')

    # Plot predicted test values.
    cu.plt.plot(close_test.index, predicted_adj_close, color = 'green', label = 'ARIMA Predictions')

    cu.plt.title(label = f'{myticker} Adjusted Close with ARIMA{best_arima_order} Predictions', fontsize=16)
    
    cu.plt.legend()
    cu.plt.show();

    gt_train = df[df.index < cu.datetime(year = 2021, month = 3, day = 1)]
    gt_train['diff_trend_score']= gt_train['trend_score'].diff(1)

    gt_train = gt_train['diff_trend_score']

    endog = y_train.astype(float).dropna()
    exog = cu.sm.add_constant(gt_train.astype(float).dropna())

    mod = cu.sm.tsa.statespace.SARIMAX(endog, exog, order=best_arima_order, trend = 't')
    res = mod.fit()
    print(res.summary())

    preds_with_gt = res.predict()
    preds_with_gt = preds_with_gt[preds_cuttoff:]

    predicted_adj_close = cu.make_predicted_adj_close_df(start, preds_with_gt)
    predicted_adj_close = predicted_adj_close[1:]

    cu.plt.figure(figsize=(10,6))

    # Plot training data.
    cu.plt.plot(close_train.index, cu.pd.DataFrame(close_train), color = 'blue', label = 'Training Adjusted Close')

    # Plot testing data.
    cu.plt.plot(close_test.index, cu.pd.DataFrame(close_test), color = 'orange', label = 'Testing Adjusted Close')

    # Plot predicted test values.
    cu.plt.plot(close_test.index, predicted_adj_close, color = 'green', label = 'ARIMAX Predictions')

    cu.plt.title(label = f'{myticker} Adjusted Close with ARIMAX Predictions', fontsize=16)
    cu.plt.legend()
    cu.plt.show();

    test = 'ssr_chi2test'
    print(cu.grangers_causation_matrix(df, variables = ['adjusted_close', 'trend_score']))

    df['trend_score_diff'] = df['trend_score'].diff(1)

    df = df[['adjusted_close', 'trend_score']]

    #train_test_split
    nobs = 30
    df_train, df_test = df[0:-nobs], df[-nobs:]

    df_differenced = df_train.diff().dropna()

    model = cu.VAR(df_differenced)

    lowest = 100_000
    for i in [1,2,3,4,5,6,7,8,9]:
        #print(i)
        result = model.fit(i)
        #print('Lag Order =', i)
        #print('AIC : ', result.aic)
        if result.aic < lowest:
            lowest = result.aic
            best_lag = i


    print(f'best lag: {best_lag}')
    print(f'best AIC: {lowest}')

    var = model.fit(best_lag)

    print(var.summary())

    forecast_input = df_differenced.values[-best_lag:]

    fc = var.forecast(y=forecast_input, steps=nobs)
    df_forecast = cu.pd.DataFrame(fc, index=df_test.index[-nobs:], columns=df_train.columns + '_2d')

    df_results = cu.invert_transformation(df_train, df_forecast, second_diff=True)

    predicted_adj_close = df_results['adjusted_close_forecast']

    close_test = df_test[df_test.index > cu.datetime(year = 2021, month = 3, day = 1)]

    cu.plt.figure(figsize=(10,6))

    # Plot testing data.
    cu.plt.plot(close_test.index, cu.pd.DataFrame(close_test)['adjusted_close'], color = 'orange', label = 'Testing Adjusted Close')

    # Plot predicted test values.
    cu.plt.plot(predicted_adj_close.index, predicted_adj_close, color = 'green', label = 'VAR Predictions')

    cu.plt.title(label = f'{myticker} Adjusted Close and Google Trends Score with VAR Predictions', fontsize=16)
    cu.plt.legend()
    cu.plt.show();

    close_train = df[df.index < cu.datetime(year = 2021, month = 4, day = 21)]
    close_train = close_train['adjusted_close']
    close_train = cu.pd.DataFrame(close_train)
    close_test = cu.pd.DataFrame(close_test)

    predicted_adj_close = df_results['adjusted_close_forecast']

    cu.plt.figure(figsize=(10,6))

    # Plot training data.
    cu.plt.plot(close_train.index, cu.pd.DataFrame(close_train), color = 'blue', label = 'Training Adjusted Close')
    # Plot training data.

    # Plot testing data.
    cu.plt.plot(close_test.index, cu.pd.DataFrame(close_test)['adjusted_close'], color = 'orange', label = 'Testing Adjusted Close')
    # Plot predicted test values.
    cu.plt.plot(close_test.index, predicted_adj_close, color = 'green', label = 'VAR Predictions')
    cu.plt.title(label = f'{myticker} Adjusted Close with VAR Predictions', fontsize=16)
    cu.plt.legend()
    cu.plt.show();
    print('done')

# %% [markdown]
# ---

# %%
model_ticker('SPY')
# Out:
# MODEL FINISHED!
# Our model that minimizes AIC on the training data is the ARIMA(2,1,3).
# This model has an AIC of -4594.303092910557.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       daily_pct_return   No. Observations:                  793
# Model:               SARIMAX(2, 1, 3)   Log Likelihood                2261.568
# Date:                Fri, 16 Jul 2021   AIC                          -4505.135
# Time:                        15:44:26   BIC                          -4463.064
# Sample:                             0   HQIC                         -4488.966
#                                 - 793
# Covariance Type:                  opg
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# drift            -1.407e-07   4.47e-07     -0.315      0.753   -1.02e-06    7.35e-07
# const                     0    4.3e-12          0      1.000   -8.44e-12    8.44e-12
# diff_trend_score    -0.0007      0.000     -4.900      0.000      -0.001      -0.000
# ar.L1               -1.4147      0.067    -20.985      0.000      -1.547      -1.283
# ar.L2               -0.5379      0.053    -10.119      0.000      -0.642      -0.434
# ma.L1                0.3699      0.074      5.021      0.000       0.226       0.514
# ma.L2               -0.6916      0.044    -15.646      0.000      -0.778      -0.605
# ma.L3               -0.2632      0.060     -4.412      0.000      -0.380      -0.146
# sigma2               0.0002   5.45e-06     35.849      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.36   Jarque-Bera (JB):              3480.77
# Prob(Q):                              0.24   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.81   Skew:                             0.43
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.17e+17. Standard errors may be unstable.
#                   adjusted_close_x  trend_score_x
# adjusted_close_y             1.000         0.0005
# trend_score_y                0.194         1.0000
# best lag: 9
# best AIC: 4.145063749646447
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 16, Jul, 2021
# Time:                     15:44:27
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    4.36351
# Nobs:                     819.000    HQIC:                   4.22889
# Log likelihood:          -3983.62    FPE:                    63.1227
# AIC:                      4.14506    Det(Omega_mle):         60.2928
# --------------------------------------------------------------------
# Results for equation adjusted_close
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                     0.170092         0.128028            1.329           0.184
# L1.adjusted_close        -0.111515         0.035084           -3.179           0.001
# L1.trend_score            0.097666         0.059104            1.652           0.098
# L2.adjusted_close         0.090918         0.035252            2.579           0.010
# L2.trend_score           -0.097269         0.059195           -1.643           0.100
# L3.adjusted_close         0.072275         0.035056            2.062           0.039
# L3.trend_score           -0.179524         0.059295           -3.028           0.002
# L4.adjusted_close        -0.069273         0.034866           -1.987           0.047
# L4.trend_score            0.015986         0.059618            0.268           0.789
# L5.adjusted_close        -0.008157         0.034957           -0.233           0.815
# L5.trend_score           -0.052097         0.059574           -0.874           0.382
# L6.adjusted_close        -0.122432         0.034900           -3.508           0.000
# L6.trend_score            0.062901         0.059470            1.058           0.290
# L7.adjusted_close         0.145007         0.034843            4.162           0.000
# L7.trend_score           -0.008007         0.059511           -0.135           0.893
# L8.adjusted_close        -0.059833         0.035049           -1.707           0.088
# L8.trend_score           -0.003044         0.059482           -0.051           0.959
# L9.adjusted_close         0.144517         0.034840            4.148           0.000
# L9.trend_score           -0.085323         0.059355           -1.437           0.151
# ====================================================================================
#
# Results for equation trend_score
# ====================================================================================
#                        coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------------
# const                     0.008964         0.076321            0.117           0.906
# L1.adjusted_close        -0.015812         0.020914           -0.756           0.450
# L1.trend_score           -0.001402         0.035233           -0.040           0.968
# L2.adjusted_close        -0.023483         0.021015           -1.117           0.264
# L2.trend_score           -0.005209         0.035288           -0.148           0.883
# L3.adjusted_close         0.001844         0.020898            0.088           0.930
# L3.trend_score            0.001284         0.035347            0.036           0.971
# L4.adjusted_close        -0.019045         0.020784           -0.916           0.359
# L4.trend_score            0.058392         0.035540            1.643           0.100
# L5.adjusted_close         0.031665         0.020839            1.520           0.129
# L5.trend_score            0.040938         0.035514            1.153           0.249
# L6.adjusted_close        -0.016222         0.020805           -0.780           0.436
# L6.trend_score           -0.006162         0.035452           -0.174           0.862
# L7.adjusted_close        -0.022985         0.020771           -1.107           0.268
# L7.trend_score           -0.006315         0.035476           -0.178           0.859
# L8.adjusted_close        -0.000047         0.020894           -0.002           0.998
# L8.trend_score           -0.001246         0.035459           -0.035           0.972
# L9.adjusted_close        -0.019109         0.020769           -0.920           0.358
# L9.trend_score           -0.116848         0.035383           -3.302           0.001
# ====================================================================================
#
# Correlation matrix of residuals
#                   adjusted_close  trend_score
# adjusted_close          1.000000    -0.098677
# trend_score            -0.098677     1.000000
# done
